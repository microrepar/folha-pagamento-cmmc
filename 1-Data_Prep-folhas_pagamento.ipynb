# %% [markdown]
# ## Organograma
#
# Evolução história dos vencimentos dos servidores
#
# ### Data Sources
# - file1 : Description of where this file came from
#
# ### Changes
# - 07-01-2023 : Started project

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime
import chardet

# %% [markdown]
# ### File Locations

# %%
today = datetime.today()
raw_dir = Path.cwd() / "data" / "raw"
summary_file = Path.cwd() / "data" / "processed" / f"summary_file.pkl"
processed_dir = Path.cwd() / "data" / "processed"

# %%
lista_folhas_xlsx = list(raw_dir.glob('*.xlsx'))
print('Qtde arquivos encontrados', len([f.name for f in lista_folhas_xlsx]))
print('Nome primeiro arquivo:', ([f.name for f in lista_folhas_xlsx])[0])
print('Nome último arquivo:', ([f.name for f in lista_folhas_xlsx])[-1])
# Out:
# Qtde arquivos encontrados 73
# Nome primeiro arquivo: 2017-07.xlsx
# Nome último arquivo: 2023-07.xlsx

# %%
with lista_folhas_xlsx[0].open(mode='rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
dtypes = {
    'Matrícula' : str,
}

df_dict ={f"df_{xlsx.name.split('.')[0].replace('-', '_')}": pd.read_excel(xlsx, skiprows=11, dtype=dtypes) for xlsx in lista_folhas_xlsx}

# %%
df_dict['df_2017_07'].head(5)
# Out:
#   Matrícula                   Nome                       Secretaria  \
# 0    000028  RAIMUNDO ANTONIO LUIZ     Secretaria Geral Legislativa
# 1    000028  RAIMUNDO ANTONIO LUIZ     Secretaria Geral Legislativa
# 2    000091    PEDRO HIDEKI KOMURA                       Vereadores
# 3    000148   JOSE ROBERTO RIBEIRO  Secretaria Geral Administrativa
# 4    000148   JOSE ROBERTO RIBEIRO  Secretaria Geral Administrativa
#
#              Local de Trabalho                 Cargo  Escolaridade  \
# 0      Departamento Financeiro      Chefe de Divisço           NaN
# 1      Departamento Financeiro      Chefe de Divisço           NaN
# 2                     Inativos  Presidente da Camara           NaN
# 3  Departamento Administrativo             Motorista           NaN
# 4  Departamento Administrativo             Motorista           NaN
#
#   Tempo de Casa Data Admissão Data Demissão        Tipo Folha  \
# 0     39 ano(s)    28/01/1982    03/11/2021      Adiantamento
# 1     39 ano(s)    28/01/1982    03/11/2021  Pagamento Mensal
# 2     30 ano(s)    01/01/1993           NaN  Pagamento Mensal
# 3     26 ano(s)    03/07/1995    01/10/2021  Pagamento Mensal
# 4     26 ano(s)    03/07/1995    01/10/2021      Adiantamento
#
#                Condição  Fun_Id  Tpf_Id  Cnd_Id  Salário Bruto  \
# 0                 Ativo      28       1       1        3300.09
# 1                 Ativo      28       6       1       19416.31
# 2  Sem Remunera‡Æo Fixa      91       6       2       12959.15
# 3                 Ativo     148       6       1        4721.68
# 4                 Ativo     148       1       1        1216.33
#
#    Salário Líquido
# 0             3300
# 1             3361
# 2             7840
# 3             2333
# 4             1216

# %% [markdown]
# ### Column Cleanup
#
# - Remove all leading and trailing spaces
# - Rename the columns for consistency.

# %%
# https://stackoverflow.com/questions/30763351/removing-space-in-dataframe-python
for df in df_dict.values():
    df.columns = [x.strip() for x in df.columns]
{col: '' for col in df_dict[list(df_dict.keys())[0]].columns}
# Out:
# {'Matrícula': '',
#  'Nome': '',
#  'Secretaria': '',
#  'Local de Trabalho': '',
#  'Cargo': '',
#  'Escolaridade': '',
#  'Tempo de Casa': '',
#  'Data Admissão': '',
#  'Data Demissão': '',
#  'Tipo Folha': '',
#  'Condição': '',
#  'Fun_Id': '',
#  'Tpf_Id': '',
#  'Cnd_Id': '',
#  'Salário Bruto': '',
#  'Salário Líquido': ''}

# %%
cols_to_rename = {
    'Matrícula': 'matricula',
    'Nome': 'nome',
    'Secretaria': 'secretaria',
    'Local de Trabalho': 'local',
    'Cargo': 'cargo',
    'Escolaridade': 'escolaridade',
    'Tempo de Casa': 'tempo',
    'Data Admissão': 'admissao',
    'Data Demissão': 'demissao',
    'Tipo Folha': 'tipo_folha',
    'Condição': 'condicao',
    'Fun_Id': 'id_matricula',
    'Salário Bruto': 'valor_bruto',
    'Salário Líquido': 'valor_liquido'
}


for df in df_dict.values():
    df.rename(columns=cols_to_rename, inplace=True)

# %%
from pprint import pprint

contador_dict = dict()
for df in df_dict.values():
    for col in df.columns:
        contador_dict.setdefault(col, 0)
        contador_dict[col] += 1
pprint(contador_dict)
# Out:
# {'Cnd_Id': 73,
#  'Tpf_Id': 73,
#  'admissao': 73,
#  'cargo': 73,
#  'condicao': 73,
#  'demissao': 73,
#  'escolaridade': 73,
#  'id_matricula': 73,
#  'local': 73,
#  'matricula': 73,
#  'nome': 73,
#  'secretaria': 73,
#  'tempo': 73,
#  'tipo_folha': 73,
#  'valor_bruto': 73,
#  'valor_liquido': 73}

# %% [markdown]
# ### Clean Up Data Types

# %%
df.dtypes
# Out:
# matricula         object
# nome              object
# secretaria        object
# local             object
# cargo             object
# escolaridade     float64
# tempo             object
# admissao          object
# demissao         float64
# tipo_folha        object
# condicao          object
# id_matricula       int64
# Tpf_Id             int64
# Cnd_Id             int64
# valor_bruto      float64
# valor_liquido      int64
# dtype: object

# %%
for nome, df in df_dict.items():
    _, df['ano'], df['mes'] = nome.split('_')
    df['competencia'] = f"{nome.split('_')[1]}-{nome.split('_')[-1]}"

df_dict[list(df_dict.keys())[0]].head(3)
# Out:
#   matricula                   nome                    secretaria  \
# 0    000028  RAIMUNDO ANTONIO LUIZ  Secretaria Geral Legislativa
# 1    000028  RAIMUNDO ANTONIO LUIZ  Secretaria Geral Legislativa
# 2    000091    PEDRO HIDEKI KOMURA                    Vereadores
#
#                      local                 cargo  escolaridade      tempo  \
# 0  Departamento Financeiro      Chefe de Divisço           NaN  39 ano(s)
# 1  Departamento Financeiro      Chefe de Divisço           NaN  39 ano(s)
# 2                 Inativos  Presidente da Camara           NaN  30 ano(s)
#
#      admissao    demissao        tipo_folha              condicao  \
# 0  28/01/1982  03/11/2021      Adiantamento                 Ativo
# 1  28/01/1982  03/11/2021  Pagamento Mensal                 Ativo
# 2  01/01/1993         NaN  Pagamento Mensal  Sem Remunera‡Æo Fixa
#
#    id_matricula  Tpf_Id  Cnd_Id  valor_bruto  valor_liquido   ano mes  \
# 0            28       1       1      3300.09           3300  2017  07
# 1            28       6       1     19416.31           3361  2017  07
# 2            91       6       2     12959.15           7840  2017  07
#
#   competencia
# 0     2017-07
# 1     2017-07
# 2     2017-07

# %%
# Concatena todos os dataframes
df = pd.concat(df_dict.values())
print('df.shape', df.shape)
df.head()
# Out:
# df.shape (30024, 19)
#   matricula                   nome                       secretaria  \
# 0    000028  RAIMUNDO ANTONIO LUIZ     Secretaria Geral Legislativa
# 1    000028  RAIMUNDO ANTONIO LUIZ     Secretaria Geral Legislativa
# 2    000091    PEDRO HIDEKI KOMURA                       Vereadores
# 3    000148   JOSE ROBERTO RIBEIRO  Secretaria Geral Administrativa
# 4    000148   JOSE ROBERTO RIBEIRO  Secretaria Geral Administrativa
#
#                          local                 cargo  escolaridade      tempo  \
# 0      Departamento Financeiro      Chefe de Divisço           NaN  39 ano(s)
# 1      Departamento Financeiro      Chefe de Divisço           NaN  39 ano(s)
# 2                     Inativos  Presidente da Camara           NaN  30 ano(s)
# 3  Departamento Administrativo             Motorista           NaN  26 ano(s)
# 4  Departamento Administrativo             Motorista           NaN  26 ano(s)
#
#      admissao    demissao        tipo_folha              condicao  \
# 0  28/01/1982  03/11/2021      Adiantamento                 Ativo
# 1  28/01/1982  03/11/2021  Pagamento Mensal                 Ativo
# 2  01/01/1993         NaN  Pagamento Mensal  Sem Remunera‡Æo Fixa
# 3  03/07/1995  01/10/2021  Pagamento Mensal                 Ativo
# 4  03/07/1995  01/10/2021      Adiantamento                 Ativo
#
#    id_matricula  Tpf_Id  Cnd_Id  valor_bruto  valor_liquido   ano mes  \
# 0            28       1       1      3300.09           3300  2017  07
# 1            28       6       1     19416.31           3361  2017  07
# 2            91       6       2     12959.15           7840  2017  07
# 3           148       6       1      4721.68           2333  2017  07
# 4           148       1       1      1216.33           1216  2017  07
#
#   competencia
# 0     2017-07
# 1     2017-07
# 2     2017-07
# 3     2017-07
# 4     2017-07

# %%
df.dtypes
# Out:
# matricula         object
# nome              object
# secretaria        object
# local             object
# cargo             object
# escolaridade     float64
# tempo             object
# admissao          object
# demissao          object
# tipo_folha        object
# condicao          object
# id_matricula       int64
# Tpf_Id             int64
# Cnd_Id             int64
# valor_bruto      float64
# valor_liquido      int64
# ano               object
# mes               object
# competencia       object
# dtype: object

# %% [markdown]
# ### Data Manipulation

# %%
df[df['cargo'].str.contains('INFO')]
# Out:
# Empty DataFrame
# Columns: [matricula, nome, secretaria, local, cargo, escolaridade, tempo, admissao, demissao, tipo_folha, condicao, id_matricula, Tpf_Id, Cnd_Id, valor_bruto, valor_liquido, ano, mes, competencia]
# Index: []

# %%
# Separa os valores de matricula/digio, mes/ano 
df['matricula'] = df['matricula'].str[1:]
df['matricula']
# Out:
# 0      00028
# 1      00028
# 2      00091
# 3      00148
# 4      00148
#        ...
# 452    01909
# 453    01910
# 454    01911
# 455    01912
# 456    01913
# Name: matricula, Length: 30024, dtype: object

# %%
df['matric'] = df['matricula'].astype(float)
df
# Out:
#     matricula                                 nome  \
# 0       00028                RAIMUNDO ANTONIO LUIZ
# 1       00028                RAIMUNDO ANTONIO LUIZ
# 2       00091                  PEDRO HIDEKI KOMURA
# 3       00148                 JOSE ROBERTO RIBEIRO
# 4       00148                 JOSE ROBERTO RIBEIRO
# ..        ...                                  ...
# 452     01909  MARLI VASCONCELOS GARCIA CAVALHEIRO
# 453     01910             EVERTON CARDOSO DE SOUSA
# 454     01911       VANESSA DOS SANTOS LUCAS PAULA
# 455     01912      PEDRO IVO VIEIRA ALVES DE SOUSA
# 456     01913       RUBENS ROBSON DE MATOS RIBEIRO
#
#                           secretaria                        local  \
# 0       Secretaria Geral Legislativa      Departamento Financeiro
# 1       Secretaria Geral Legislativa      Departamento Financeiro
# 2                         Vereadores                     Inativos
# 3    Secretaria Geral Administrativa  Departamento Administrativo
# 4    Secretaria Geral Administrativa  Departamento Administrativo
# ..                               ...                          ...
# 452     Secretaria Geral Legislativa      Departamento Financeiro
# 453     Secretaria Geral Legislativa      Departamento Financeiro
# 454     Secretaria Geral Legislativa      Departamento Financeiro
# 455     Secretaria Geral Legislativa      Departamento Financeiro
# 456     Secretaria Geral Legislativa      Departamento Financeiro
#
#                                             cargo  escolaridade      tempo  \
# 0                                Chefe de Divisço           NaN  39 ano(s)
# 1                                Chefe de Divisço           NaN  39 ano(s)
# 2                            Presidente da Camara           NaN  30 ano(s)
# 3                                       Motorista           NaN  26 ano(s)
# 4                                       Motorista           NaN  26 ano(s)
# ..                                            ...           ...        ...
# 452  Assessor para Assuntos Politico-legislativos           NaN  3 mes(es)
# 453  Assessor para Assuntos Politico-legislativos           NaN  2 mes(es)
# 454  Assessor para Assuntos Politico-legislativos           NaN  2 mes(es)
# 455  Assessor para Assuntos Politico-legislativos           NaN  2 mes(es)
# 456                        Assistente Parlamentar           NaN  2 mes(es)
#
#        admissao    demissao        tipo_folha              condicao  \
# 0    28/01/1982  03/11/2021      Adiantamento                 Ativo
# 1    28/01/1982  03/11/2021  Pagamento Mensal                 Ativo
# 2    01/01/1993         NaN  Pagamento Mensal  Sem Remunera‡Æo Fixa
# 3    03/07/1995  01/10/2021  Pagamento Mensal                 Ativo
# 4    03/07/1995  01/10/2021      Adiantamento                 Ativo
# ..          ...         ...               ...                   ...
# 452  29/06/2023         NaN  Pagamento Mensal                 Ativo
# 453  12/07/2023         NaN  Pagamento Mensal                 Ativo
# 454  07/07/2023         NaN  Pagamento Mensal                 Ativo
# 455  24/07/2023         NaN  Pagamento Mensal                 Ativo
# 456  19/07/2023         NaN  Pagamento Mensal                 Ativo
#
#      id_matricula  Tpf_Id  Cnd_Id  valor_bruto  valor_liquido   ano mes  \
# 0              28       1       1      3300.09           3300  2017  07
# 1              28       6       1     19416.31           3361  2017  07
# 2              91       6       2     12959.15           7840  2017  07
# 3             148       6       1      4721.68           2333  2017  07
# 4             148       1       1      1216.33           1216  2017  07
# ..            ...     ...     ...          ...            ...   ...  ..
# 452          1909       6       1      6474.36           3227  2023  07
# 453          1910       6       1      3844.15           3414  2023  07
# 454          1911       6       1      4855.77           4028  2023  07
# 455          1912       6       1      1416.27           1309  2023  07
# 456          1913       6       1      2757.12           2229  2023  07
#
#     competencia  matric
# 0       2017-07    28.0
# 1       2017-07    28.0
# 2       2017-07    91.0
# 3       2017-07   148.0
# 4       2017-07   148.0
# ..          ...     ...
# 452     2023-07  1909.0
# 453     2023-07  1910.0
# 454     2023-07  1911.0
# 455     2023-07  1912.0
# 456     2023-07  1913.0
#
# [30024 rows x 20 columns]

# %% [markdown]
# ### Normalização de cargos

# %%
df['cargo'] = df['cargo'].str.upper()
df['cargo_normalizado'] = df['cargo']

# %%
df['cargo_normalizado'] = df['cargo_normalizado'].replace(
    {'ASSESSOR ESPECIAL PARLAMENTAR'                  : 'ASSESSOR',
    'ASSESSOR PARA ASSUNTOS POLITICO-LEGISLATIVOS'    : 'ASSESSOR',
    'ASSESSOR DE CERIMONIAL'                          : 'ASSESSOR',
    'ASSESSOR LEGISLATIVO FINANCEIRO'                 : 'ASSESSOR',
    'ASSESSOR PARLAMENTAR DE GABINETE DA PRESIDENCIA' : 'ASSESSOR'}
)

{c: '' for c in df[['matricula', 'nome', 'cargo', 'cargo_normalizado']][df['cargo_normalizado'].str.upper().str.contains(r'^ASSES', regex=True)]['cargo_normalizado'].unique()}
# Out:
# {'ASSESSOR': ''}

# %%
df['cargo_normalizado'] = df['cargo_normalizado'].replace(
    {'PROCURADOR JURIDICO'      : 'PROCURADOR JURIDICO',
    'PROCURADOR JURIDICO CHEFE' : 'PROCURADOR JURIDICO'}
)

{c: '' for c in df[['matricula', 'nome', 'cargo', 'cargo_normalizado']][df['cargo_normalizado'].str.upper().str.contains(r'PROCUR', regex=True)]['cargo_normalizado'].unique()}
# Out:
# {'PROCURADOR JURIDICO': ''}

# %%
df['cargo_normalizado'] = df['cargo_normalizado'].replace(
    {'SECRETARIO GERAL LEGISLATIVO'   : 'SECRETARIO GERAL',
    'SECRETARIO GERAL ADMINISTRATIVO' : 'SECRETARIO GERAL'}
)

{c: '' for c in df[['matricula', 'nome', 'cargo', 'cargo_normalizado']][df['cargo_normalizado'].str.upper().str.contains(r'SECRET', regex=True)]['cargo_normalizado'].unique()}
# Out:
# {'SECRETARIO GERAL': ''}

# %%
df['cargo_normalizado'] = df['cargo_normalizado'].replace(
    {'CHEFE DE DIVISÇO'               : 'CHEFE',
    'CHEFE DA ASSESSORIA LEGISLATIVA' : 'CHEFE',
    'CHEFE DE GABINETE PARLAMENTAR'   : 'CHEFE'}
)

{c: '' for c in df[['matricula', 'nome', 'cargo', 'cargo_normalizado']][df['cargo_normalizado'].str.upper().str.contains(r'CHEFE', regex=True)]['cargo_normalizado'].unique()}
# Out:
# {'CHEFE': ''}

# %%
df['cargo_normalizado'] = (df['cargo_normalizado']
                           .str.replace('"', ' ', regex=False)
                           .str.replace('/', '-', regex=False)                           
                           )

# %%
df['comp'] = df['competencia']
df['comp']
# Out:
# 0      2017-07
# 1      2017-07
# 2      2017-07
# 3      2017-07
# 4      2017-07
#         ...
# 452    2023-07
# 453    2023-07
# 454    2023-07
# 455    2023-07
# 456    2023-07
# Name: comp, Length: 30024, dtype: object

# %%
df.dtypes
# Out:
# matricula             object
# nome                  object
# secretaria            object
# local                 object
# cargo                 object
# escolaridade         float64
# tempo                 object
# admissao              object
# demissao              object
# tipo_folha            object
# condicao              object
# id_matricula           int64
# Tpf_Id                 int64
# Cnd_Id                 int64
# valor_bruto          float64
# valor_liquido          int64
# ano                   object
# mes                   object
# competencia           object
# matric               float64
# cargo_normalizado     object
# comp                  object
# dtype: object

# %% [markdown]
# ### Save output file into processed directory
#
# Save a file in the processed directory that is cleaned properly. It will be read in and used later for further analysis.
#
# Other options besides pickle include:
# - feather
# - msgpack
# - parquet

# %%
# df.to_pickle(summary_file)
import contextlib
ano = int(max(df['ano'].unique()))
mes = int(max(df[df['ano'] == str(ano)]['mes'].unique()))
ano = f'{ano:0>4}'
mes = f'{mes:0>2}'

matriculas_ultimo_mes = list(df[(df['ano'] == ano) & (df['mes'] == mes)]['matricula'].unique())
print(len(matriculas_ultimo_mes))

configuracoes = ['ano', 'mes', 'cargo_normalizado']
for config in configuracoes:
    unique_values = df[config].unique()
    for value in unique_values:
        if config == 'cargo_normalizado':
            value = value.replace('"', ' ')
            value = value.replace("/", ' ')

        with contextlib.suppress(FileExistsError):
            destino = (Path.cwd() / 'data')
            destino.mkdir()
        with contextlib.suppress(FileExistsError):
            destino = (destino / 'processed')
            destino.mkdir()
        with contextlib.suppress(FileExistsError):
            destino = (destino / config)
            destino.mkdir()
            
        if config == 'matricula':           
            value = f'{value:0<5}'
            
            if value in matriculas_ultimo_mes:
                destino = destino / f"{value}.parquet"
                df[(df[config] == value)].to_parquet(destino)
                
        else:
            destino = destino / f"{value:0>2}.parquet"
            df[df[config] == value].to_parquet(destino)
# Out:
# 231
